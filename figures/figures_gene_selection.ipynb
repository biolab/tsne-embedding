# %%
from examples import utils

import anndata
import numpy as np
import pandas as pd
import scipy.sparse as sp
import string

import matplotlib.pyplot as plt

# %% [markdown]
# # Baron

# %%
adata_250 = anndata.read_h5ad("embedding_tsne_250_genes.h5ad")
adata_3000 = anndata.read_h5ad("embedding_tsne_3000_genes.h5ad")
adata_full = anndata.read_h5ad("embedding_tsne_all_genes.h5ad")

# %%
colors = {
    'Beta cells': '#1f77b4',
    'Alpha cells': '#ff7f0e',
    'Delta cells': '#2ca02c',
    'PP cells': '#d62728',
    'Epsilon cells': '#9467bd',
    
    'Ductal cells': '#8c564b',
    'Acinar cells': '#e377c2',
    'PaSC': '#bcbd22',
    
    'Endothelial cell': '#17becf',
    'Macrophage': "#7f7f7f",
    "Mast cell": "#7f7f7f",
    "Schwann cell": "#7f7f7f",
    "T cell": "#7f7f7f",
    "Other": "#7f7f7f",
}
assert all(l in colors for l in adata_250.obs["labels"].unique())

# %%
print(adata_full.shape[1], "genes")
# Out:
# 17499 genes

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_250.obs["labels"]))

fig, ax = plt.subplots(ncols=3, figsize=(15, 5))

utils.plot(adata_250.obsm["tsne"], adata_250.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0], alpha=1, title="250 genes", label_order=cell_order)
utils.plot(adata_3000.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1], alpha=1, title="3,000 genes", label_order=cell_order)
utils.plot(adata_full.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[2], alpha=1, title="17,499 genes", label_order=cell_order,
          legend_kwargs=dict(loc="upper center", bbox_to_anchor=(0.5, 0.05), bbox_transform=fig.transFigure, labelspacing=1, ncol=num_cell_types // 2 + 1))

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax: ax_.axis("equal")

plt.savefig("baron_embedding_tsne_genes.pdf", dpi=600, bbox_inches="tight", transparent=True)

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_250.obs["labels"]))

fig, ax = plt.subplots(nrows=3, figsize=(5, 15))

utils.plot(adata_250.obsm["tsne"], adata_250.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0], alpha=1, title="250 genes", label_order=cell_order)
utils.plot(adata_3000.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1], alpha=1, title="3,000 genes", label_order=cell_order)
utils.plot(adata_full.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[2], alpha=1, title="17,499 genes", label_order=cell_order,
          legend_kwargs=dict(loc="center", bbox_to_anchor=(1.1, 0.5), bbox_transform=fig.transFigure, labelspacing=1, ncol=1))

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")
for ax_ in ax: ax_.axis("equal")

# %% [markdown]
# # Hrvatin

# %%
adata_250 = anndata.read_h5ad("hrvatin_embedding_tsne_250_genes.h5ad")
adata_3000 = anndata.read_h5ad("hrvatin_embedding_tsne_3000_genes.h5ad")
adata_full = anndata.read_h5ad("hrvatin_embedding_tsne_all_genes.h5ad")

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b',
          '#7f7f7f', # This is the grey one
          '#e377c2', '#bcbd22', '#17becf']

colors = dict(zip(adata_250.obs["labels"].value_counts().sort_values(ascending=False).index, colors))

#colors["Other"] = '#7f7f7f'

assert all(l in colors for l in adata_250.obs["labels"].unique())

# %%
print(adata_full.shape[1], "genes")
# Out:
# 20394 genes

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_250.obs["labels"]))

fig, ax = plt.subplots(ncols=3, figsize=(15, 5))

utils.plot(adata_250.obsm["tsne"], adata_250.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0], alpha=1, title="250 genes", label_order=cell_order)
utils.plot(adata_3000.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1], alpha=1, title="3,000 genes", label_order=cell_order)
utils.plot(adata_full.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[2], alpha=1, title="20,394 genes", label_order=cell_order,
          legend_kwargs=dict(loc="upper center", bbox_to_anchor=(0.5, 0.05), bbox_transform=fig.transFigure, labelspacing=1, ncol=num_cell_types // 2 + 1))

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax: ax_.axis("equal")

plt.savefig("hrvatin_embedding_tsne_genes.pdf", dpi=600, bbox_inches="tight", transparent=True)

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_250.obs["labels"]))

fig, ax = plt.subplots(nrows=3, figsize=(5, 15))

utils.plot(adata_250.obsm["tsne"], adata_250.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0], alpha=1, title="250 genes", label_order=cell_order)
utils.plot(adata_3000.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1], alpha=1, title="3,000 genes", label_order=cell_order)
utils.plot(adata_full.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[2], alpha=1, title="20,394 genes", label_order=cell_order,
          legend_kwargs=dict(loc="center", bbox_to_anchor=(1.1, 0.5), bbox_transform=fig.transFigure, labelspacing=1, ncol=1))

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax: ax_.axis("equal")

# %% [markdown]
# # Macosko

# %%
adata_250 = anndata.read_h5ad("macosko_embedding_tsne_250_genes.h5ad")
adata_3000 = anndata.read_h5ad("macosko_embedding_tsne_3000_genes.h5ad")
adata_full = anndata.read_h5ad("macosko_embedding_tsne_10000_genes.h5ad")

# %%
colors = utils.MACOSKO_COLORS

# %%
print(adata_full.shape[1], "genes")
# Out:
# 10010 genes

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_250.obs["labels"]))

fig, ax = plt.subplots(ncols=3, figsize=(15, 5))

utils.plot(adata_250.obsm["tsne"], adata_250.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0], alpha=1, title="250 genes", label_order=cell_order)
utils.plot(adata_3000.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1], alpha=1, title="3,000 genes", label_order=cell_order)
utils.plot(adata_full.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[2], alpha=1, title="10,010 genes", label_order=cell_order,
          legend_kwargs=dict(loc="upper center", bbox_to_anchor=(0.5, 0.05), bbox_transform=fig.transFigure, labelspacing=1, ncol=num_cell_types // 2 + 1))

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax: ax_.axis("equal")

plt.savefig("macosko_embedding_tsne_genes.pdf", dpi=600, bbox_inches="tight", transparent=True)

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_250.obs["labels"]))

fig, ax = plt.subplots(nrows=3, figsize=(5, 15))

utils.plot(adata_250.obsm["tsne"], adata_250.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0], alpha=1, title="250 genes", label_order=cell_order)
utils.plot(adata_3000.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1], alpha=1, title="3,000 genes", label_order=cell_order)
utils.plot(adata_full.obsm["tsne"], adata_250.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[2], alpha=1, title="20,394 genes", label_order=cell_order,
          legend_kwargs=dict(loc="center", bbox_to_anchor=(1.15, 0.5), bbox_transform=fig.transFigure, labelspacing=1, ncol=1))

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax: ax_.axis("equal")
