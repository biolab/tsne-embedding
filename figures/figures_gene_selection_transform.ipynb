# %%
from os import path

import sys
sys.path.append(path.join("..", "notebooks"))
sys.path.append(path.join("..", "notebooks", "utils.py"))
import utils

import anndata
import numpy as np
import pandas as pd
import scipy.sparse as sp
import string

import matplotlib.pyplot as plt

# %% [markdown]
# # Baron

# %%
adata_3000 = anndata.read_h5ad("baron_embedding_tsne_3000_genes.h5ad")

new_250 = anndata.read_h5ad("baron_transform_tsne_250_genes.h5ad")
new_1000 = anndata.read_h5ad("baron_transform_tsne_1000_genes.h5ad")
new_full = anndata.read_h5ad("baron_transform_tsne_all_genes.h5ad")

# %%
colors = utils.get_colors_for(adata_3000)

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_3000.obs["labels"]))

fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(12, 12))

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0, 0], alpha=0.1, title="Initialization", label_order=cell_order)
utils.plot(new_250.obsm["tsne_init"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[0, 0], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[0, 1], alpha=0.1, title="250 genes", label_order=cell_order)
utils.plot(new_250.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[0, 1], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1, 0], alpha=0.1, title="1,000 genes", label_order=cell_order)
utils.plot(new_1000.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[1, 0], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[1, 1], alpha=0.1, title="5,000 genes", label_order=cell_order,
          legend_kwargs=dict(loc="upper center", bbox_to_anchor=(0.5, 0.05), bbox_transform=fig.transFigure, labelspacing=1, ncol=num_cell_types // 2 + 1))
utils.plot(new_full.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[1, 1], alpha=1, label_order=cell_order)

for ax_, letter in zip(ax.ravel(), string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax.ravel(): ax_.axis("equal")
    
coord_range = -43, 43
for ax_ in ax.ravel():
    ax_.set_xlim(*coord_range), ax_.set_ylim(*coord_range)

plt.savefig("baron_transform_tsne_genes.pdf", dpi=600, bbox_inches="tight", transparent=True)

# %% [markdown]
# # Hrvatin

# %%
adata_3000 = anndata.read_h5ad("hrvatin_embedding_tsne_3000_genes.h5ad")

new_250 = anndata.read_h5ad("hrvatin_transform_tsne_250_genes.h5ad")
new_1000 = anndata.read_h5ad("hrvatin_transform_tsne_1000_genes.h5ad")
new_5000 = anndata.read_h5ad("hrvatin_transform_tsne_5000_genes.h5ad")

# %%
colors = utils.get_colors_for(adata_3000)

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_3000.obs["labels"]))

fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(12, 12))

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0, 0], alpha=0.1, title="Initialization", label_order=cell_order)
utils.plot(new_250.obsm["tsne_init"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[0, 0], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[0, 1], alpha=0.1, title="250 genes", label_order=cell_order)
utils.plot(new_250.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[0, 1], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1, 0], alpha=0.1, title="1,000 genes", label_order=cell_order)
utils.plot(new_1000.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[1, 0], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[1, 1], alpha=0.1, title="5,000 genes", label_order=cell_order,
          legend_kwargs=dict(loc="upper center", bbox_to_anchor=(0.5, 0.05), bbox_transform=fig.transFigure, labelspacing=1, ncol=num_cell_types // 2 + 1))
utils.plot(new_5000.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[1, 1], alpha=1, label_order=cell_order)

for ax_, letter in zip(ax.ravel(), string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax.ravel(): ax_.axis("equal")

plt.savefig("hrvatin_transform_tsne_genes.pdf", dpi=600, bbox_inches="tight", transparent=True)

# %% [markdown]
# # Macosko

# %%
adata_3000 = anndata.read_h5ad("macosko_embedding_tsne_3000_genes.h5ad")

new_250 = anndata.read_h5ad("macosko_transform_tsne_250_genes.h5ad")
new_1000 = anndata.read_h5ad("macosko_transform_tsne_1000_genes.h5ad")
new_5000 = anndata.read_h5ad("macosko_transform_tsne_5000_genes.h5ad")

# %%
colors = utils.MACOSKO_COLORS

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata_3000.obs["labels"]))

fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(12, 12))

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"],  s=1, colors=colors, draw_legend=False, ax=ax[0, 0], alpha=0.1, title="Initialization", label_order=cell_order)
utils.plot(new_250.obsm["tsne_init"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[0, 0], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[0, 1], alpha=0.1, title="250 genes", label_order=cell_order)
utils.plot(new_250.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[0, 1], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=False, ax=ax[1, 0], alpha=0.1, title="1,000 genes", label_order=cell_order)
utils.plot(new_1000.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[1, 0], alpha=1, label_order=cell_order)

utils.plot(adata_3000.obsm["tsne"], adata_3000.obs["labels"], s=1, colors=colors, draw_legend=True, ax=ax[1, 1], alpha=0.1, title="5,000 genes", label_order=cell_order,
          legend_kwargs=dict(loc="upper center", bbox_to_anchor=(0.5, 0.05), bbox_transform=fig.transFigure, labelspacing=1, ncol=num_cell_types // 3 + 1))
utils.plot(new_5000.obsm["tsne"], new_250.obs["labels"], s=3, colors=colors, draw_legend=False, ax=ax[1, 1], alpha=1, label_order=cell_order)

for ax_, letter in zip(ax.ravel(), string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

for ax_ in ax.ravel(): ax_.axis("equal")
    
coord_range = -54, 54
for ax_ in ax.ravel():
    ax_.set_xlim(*coord_range), ax_.set_ylim(*coord_range)

plt.savefig("macosko_transform_tsne_genes.pdf", dpi=600, bbox_inches="tight", transparent=True)
