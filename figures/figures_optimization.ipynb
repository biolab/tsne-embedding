# %%
from os import path

import sys
sys.path.append(path.join("..", "notebooks"))
sys.path.append(path.join("..", "notebooks", "utils.py"))
import utils

import anndata
import numpy as np
import pandas as pd
import scipy.sparse as sp
import string

import matplotlib.pyplot as plt

# %% [markdown]
# # Pancreas

# %%
adata = anndata.read_h5ad("baron_embedding_tsne_3000_genes.h5ad")
new = anndata.read_h5ad("baron_transform_tsne_1000_genes.h5ad")

# %%
colors = utils.get_colors_for(adata)

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata.obs["labels"]))
colors_bw = {1: "#666666"}

fig, ax = plt.subplots(ncols=2, figsize=(12, 6))

utils.plot(adata.obsm["tsne"], np.ones_like(adata.obs["labels"]), ax=ax[0], colors=colors_bw, alpha=0.05, s=1, draw_legend=False)
utils.plot(new.obsm["tsne_init"], new.obs["labels"], ax=ax[0], colors=colors, draw_legend=False, s=6, label_order=cell_order, alpha=1)
ax[0].set_title("Median initialization")

utils.plot(adata.obsm["tsne"], np.ones_like(adata.obs["labels"]), ax=ax[1], colors=colors_bw, alpha=0.05, s=1, draw_legend=False)
utils.plot(new.obsm["tsne"], new.obs["labels"], ax=ax[1], colors=colors, draw_legend=False, s=6, label_order=cell_order, alpha=1)
ax[1].set_title("Transformed samples")

for ax_ in ax.ravel(): ax_.axis("equal")

coord_range = -50, 50
for ax_ in ax.ravel():
    ax_.set_xlim(*coord_range), ax_.set_ylim(*coord_range)

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

plt.savefig("optimization_pancreas.pdf", dpi=600, bbox_inches="tight", transparent=True)

# %% [markdown]
# # Brain

# %%
adata = anndata.read_h5ad("hrvatin_embedding_tsne_3000_genes.h5ad")
new = anndata.read_h5ad("hrvatin_transform_tsne_1000_genes.h5ad")

# %%
colors = utils.get_colors_for(adata)

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata.obs["labels"]))
colors_bw = {1: "#666666"}

fig, ax = plt.subplots(ncols=2, figsize=(12, 6))

utils.plot(adata.obsm["tsne"], np.ones_like(adata.obs["labels"]), ax=ax[0], colors=colors_bw, alpha=0.05, s=1, draw_legend=False)
utils.plot(new.obsm["tsne_init"], new.obs["labels"], ax=ax[0], colors=colors, draw_legend=False, s=6, label_order=cell_order, alpha=1)
ax[0].set_title("Median initialization")

utils.plot(adata.obsm["tsne"], np.ones_like(adata.obs["labels"]), ax=ax[1], colors=colors_bw, alpha=0.05, s=1, draw_legend=False)
utils.plot(new.obsm["tsne"], new.obs["labels"], ax=ax[1], colors=colors, draw_legend=False, s=6, label_order=cell_order, alpha=1)
ax[1].set_title("Transformed samples")

for ax_ in ax.ravel(): ax_.axis("equal")

coord_range = -50, 50
for ax_ in ax.ravel():
    ax_.set_xlim(*coord_range), ax_.set_ylim(*coord_range)

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

plt.savefig("optimization_brain.pdf", dpi=600, bbox_inches="tight", transparent=True)

# %% [markdown]
# # Retina

# %%
adata = anndata.read_h5ad("macosko_embedding_tsne_3000_genes.h5ad")
new = anndata.read_h5ad("macosko_transform_tsne_1000_genes.h5ad")

# %%
colors = utils.MACOSKO_COLORS

# %%
cell_order = list(colors.keys())
num_cell_types = len(np.unique(adata.obs["labels"]))
colors_bw = {1: "#666666"}

fig, ax = plt.subplots(ncols=2, figsize=(12, 6))

utils.plot(adata.obsm["tsne"], np.ones_like(adata.obs["labels"]), ax=ax[0], colors=colors_bw, alpha=0.05, s=1, draw_legend=False)
utils.plot(new.obsm["tsne_init"], new.obs["labels"], ax=ax[0], colors=colors, draw_legend=False, s=6, label_order=cell_order, alpha=1)
ax[0].set_title("Median initialization")

utils.plot(adata.obsm["tsne"], np.ones_like(adata.obs["labels"]), ax=ax[1], colors=colors_bw, alpha=0.05, s=1, draw_legend=False)
utils.plot(new.obsm["tsne"], new.obs["labels"], ax=ax[1], colors=colors, draw_legend=False, s=6, label_order=cell_order, alpha=1)
ax[1].set_title("Transformed samples")

for ax_ in ax.ravel(): ax_.axis("equal")

coord_range = -50, 50
for ax_ in ax.ravel():
    ax_.set_xlim(*coord_range), ax_.set_ylim(*coord_range)

for ax_, letter in zip(ax, string.ascii_lowercase): 
    plt.text(0, 1.02, letter, transform=ax_.transAxes, fontsize=15, fontweight="bold")

plt.savefig("optimization_retina.pdf", dpi=600, bbox_inches="tight", transparent=True)
